# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("reklam.csv")

# %%
data.head()
# Out:
#    sıra     TV  radyo  gazete  satış
# 0     1  230.1   37.8    69.2   22.1
# 1     2   44.5   39.3    45.1   10.4
# 2     3   17.2   45.9    69.3    9.3
# 3     4  151.5   41.3    58.5   18.5
# 4     5  180.8   10.8    58.4   12.9

# %%
x=data.TV.values.reshape(-1,1)
y=data.satış.values

# %%
plt.scatter(x,y)
plt.xlabel("tv reklamları")
plt.ylabel("satış miktarı")
plt.show()

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=33)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
yhead=lr.predict(xtest)

# %%
ytest
# Out:
# array([22.4, 14.5, 14.7,  6.6, 12.2, 14.9, 20.2, 24.4,  9.4, 11.7, 19.8,
#         4.8, 15.9, 10.1, 10.5, 10.1, 12.3,  6.6,  6.7, 15.2, 12.8, 16.6,
#        11.4, 15.7, 19.4,  9.5, 19. , 19. ,  7.3, 11.7, 13.4, 11.7, 19.2,
#        10.6, 16.7,  8.7, 12.4,  7.6,  8.7, 14.1])

# %%
yhead
# Out:
# array([16.44947475, 14.98116282, 16.09308836,  8.08627412, 13.77895273,
#        16.11684746, 19.64744863, 20.5360387 , 10.79481069, 17.73246576,
#        19.30056588,  7.57307772, 13.13745723,  9.21245511, 10.51920521,
#         9.28848421, 18.55928219,  7.53506317,  8.05301139, 16.34493475,
#        15.57514014, 16.55401476, 16.65855477, 18.53552309, 17.50913029,
#        11.71191167, 15.30428649, 16.86288297,  8.52344143, 15.16648375,
#        18.19339216, 15.25201648, 16.36869384, 11.30800709, 12.38191808,
#         7.96747866, 12.38191808,  8.97961601,  9.83494334, 15.5133665 ])

# %%
lr.predict([[400]])
# Out:
# array([26.17169549])

# %%
plt.scatter(x,y)
plt.plot(xtest,yhead)
plt.xlabel("tv reklamları")
plt.ylabel("satış miktarı")
plt.show()

# %%
from sklearn.metric import mean_squared_error,r2_score

rmse=np.sqrt()
